# %% [markdown]
# # Test on CNN for CIFAR-10 classification

# %%
import sys
import numpy as np
import tensorflow as tf
from tensorflow import keras
import plotly.graph_objects as go
from ipywidgets import widgets

# %% [markdown]
# # Load model

# %%
model0 = keras.models.load_model('../dnnviewer-data/models/CIFAR-10_CNN5.h5')
model0.summary()

cifar10_classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_0 (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_0 (Dense)              (None, 64)                65600
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Model inspection

# %%
l = model0.layers[0]
l

# %%
len(l.get_weights())
# Out:
# 2

# %%
l.bias
# Out:
# <tf.Variable 'conv_0/bias:0' shape=(32,) dtype=float32, numpy=
# array([-0.01351038,  0.00439227, -0.00868714,  0.01078064,  0.01710911,
#         0.06611834,  0.00507954,  0.00421242, -0.3259326 ,  0.03777989,
#        -0.00120674,  0.0306607 ,  0.04180602,  0.00326504, -0.16762863,
#        -0.04841281,  0.24390614, -0.2753176 ,  0.04783649, -0.03341499,
#         0.00371281, -0.00546046, -0.00651637,  0.10717128, -0.00328693,
#        -0.00515962, -0.04666445, -0.00049873,  0.01122756, -0.02400721,
#        -0.0075548 ,  0.14836842], dtype=float32)>

# %%
l.get_weights()[1]
# Out:
# array([-0.01351038,  0.00439227, -0.00868714,  0.01078064,  0.01710911,
#         0.06611834,  0.00507954,  0.00421242, -0.3259326 ,  0.03777989,
#        -0.00120674,  0.0306607 ,  0.04180602,  0.00326504, -0.16762863,
#        -0.04841281,  0.24390614, -0.2753176 ,  0.04783649, -0.03341499,
#         0.00371281, -0.00546046, -0.00651637,  0.10717128, -0.00328693,
#        -0.00515962, -0.04666445, -0.00049873,  0.01122756, -0.02400721,
#        -0.0075548 ,  0.14836842], dtype=float32)

# %%
l.input.get_shape()
# Out:
# TensorShape([None, 32, 32, 3])

# %%
l.input_shape
# Out:
# (None, 32, 32, 3)

# %%
l.losses
# Out:
# []

# %%
l.metrics
# Out:
# []

# %%
l.output.get_shape()
# Out:
# TensorShape([None, 30, 30, 32])

# %%
l.kernel_constraint

# %%
l.kernel_regularizer

# %%
l.kernel
# Out:
# <tf.Variable 'conv_0/kernel:0' shape=(3, 3, 3, 32) dtype=float32, numpy=
# array([[[[ 7.22285211e-02,  1.59016907e-01,  1.14403367e-02,
#           -1.61757216e-01, -9.51639041e-02,  2.13496283e-01,
#            1.22781679e-01, -9.46229175e-02, -2.73989290e-01,
#            2.91213244e-01,  1.48980334e-01,  2.27229401e-01,
#            4.37679887e-02, -1.87519103e-01,  1.02188289e-01,
#            1.24463238e-01, -2.81389058e-01,  1.26477942e-01,
#            3.92462499e-02,  1.03216395e-01, -1.14730947e-01,
#           -6.94235042e-02, -2.26170700e-02,  9.68715101e-02,
#            1.13665439e-01, -2.14720577e-01, -2.18591422e-01,
#           -1.14362709e-01, -5.54827861e-02, -1.18618950e-01,
#            9.47447568e-02, -2.85548776e-01],
#          [ 1.49271443e-01, -1.25256360e-01,  7.87881985e-02,
#           -1.03191376e-01,  9.06662866e-02,  2.31157884e-01,
#            9.35103297e-02, -1.87734663e-01, -2.37348318e-01,
#           -2.10068569e-01,  1.18245974e-01,  1.87228322e-01,
#           -9.07343905e-03, -8.34523812e-02,  7.92263299e-02,
#            8.33407193e-02, -2.14441568e-02, -1.34844601e-01,
#           -1.09074809e-01, -2.05880314e-01,  5.27391285e-02,
#           -4.39006425e-02, -1.19362190e-01, -1.55399954e-02,
#            6.42649010e-02,  4.03432222e-03, -5.94325028e-02,
#            1.56536549e-02, -2.62787849e-01, -2.40976308e-02,
#           -2.39604682e-01,  7.86202624e-02, -1.18501402e-01,
#           -3.07194948e-01,  3.03734839e-02, -1.40047222e-01,
#           -3.44821960e-02, -3.86758000e-02, -1.04914635e-01,
#            1.21689074e-01,  1.13907620e-01, -6.80509210e-02,
#           -2.35319063e-01, -2.07768440e-01],
#          [-5.52958734e-02,  1.55662015e-01, -7.62628615e-02,
#            4.45188489e-04,  1.33369807e-02,  1.30677432e-01,
#           -2.09042892e-01, -1.15017489e-01, -4.38607186e-02,
#            5.64261228e-02, -1.43364370e-01, -3.22316065e-02,
#            1.74449816e-01,  2.13160962e-01, -6.80389162e-03,
#            1.41111717e-01, -4.22797292e-01, -9.05703083e-02,
#           -9.09601972e-02, -1.59249634e-01,  1.94443300e-01,
#           -2.13896051e-01,  1.49527669e-01, -1.54469371e-01,
#           -3.68579142e-02,  6.04563951e-02, -1.19530402e-01,
#            1.69989467e-01, -1.51686758e-01,  1.24480233e-01,
#           -1.06109969e-01, -2.36011967e-01],
#          [ 1.80631548e-01,  2.22642288e-01, -9.86592770e-02,
#           -6.47415146e-02,  1.77432299e-01,  2.58801561e-02,
#           -2.20257580e-01,  1.92849133e-02, -2.34727561e-01,
#            1.46111799e-02,  2.51660068e-02,  7.30919745e-03,
#            6.00213520e-02, -8.13560095e-03,  8.70316699e-02,
#            9.82309505e-03, -2.52451867e-01, -1.75630733e-01,
#            1.25891313e-01, -2.68581986e-01, -2.08536193e-01,
#           -1.29923135e-01,  3.68827879e-02, -2.25585476e-02,
#           -1.90950949e-02, -4.64747734e-02,  1.58680812e-01,
#            1.66696221e-01, -7.99552724e-02,  1.47935405e-01,
#           -1.33680567e-01, -2.75573015e-01]]]], dtype=float32)>

# %%
l.use_bias
# Out:
# True

# %%
l.padding
# Out:
# 'valid'

# %%
model0.loss
# Out:
# 'sparse_categorical_crossentropy'

# %%
model0.loss_functions[0]

# %%
model0.loss_weights

# %%
model0.metrics

# %%
model0.metrics[0].result()
# Out:
# <tf.Tensor: id=1028, shape=(), dtype=float32, numpy=0.0>

# %%
model0.optimizer

# %%
print(model0.total_loss)
# Out:
# Tensor("loss/mul:0", shape=(), dtype=float32)

# %%
gradients = model0.optimizer.get_gradients(model0.total_loss, model0.weights)

# %%
print(gradients[0][0,0,0,0])
# Out:
# Tensor("strided_slice:0", shape=(), dtype=float32)

# %%
(x_train, yTrain), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %%
with tf.GradientTape() as tape:
    y_est = model0(x_train[:1000].astype(np.float)) 
    # Loss + regularization
    objective = model0.loss_functions[0](y_train[:1000], y_est)
grads = tape.gradient(objective, model0.weights)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-af493cef5128> in <module>
#       2     y_est = model0(x_train[:1000].astype(np.float))
#       3     # Loss + regularization
# ----> 4     objective = model0.loss_functions[0](y_train[:1000], y_est)
#       5 grads = tape.gradient(objective, model0.weights)
#
# NameError: name 'y_train' is not defined

# %%
objective

# %%
grads
